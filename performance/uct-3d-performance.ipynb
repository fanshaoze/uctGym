# %%
# %matplotlib notebook
from matplotlib import pyplot as plt

import numpy as np

from mpl_toolkits.mplot3d import Axes3D

fig=plt.figure()

ax=Axes3D(fig)

xbegin = 4
xend = 30
xdis = 2

ybegin = 10
yend = 110
ydis = 10

# xbegin = 20
# xend = 30
# xdis = 1

# ybegin = 90
# yend = 100
# ydis = 1




xnum = int((xend-xbegin)/xdis)
ynum = int((yend-ybegin)/ydis)

# x=np.arange(-1,1,0.25)

# y=np.arange(-1,1,0.25)
# x = np.linspace(xbegin,xend,xdis)
# y = np.linspace(ybegin,yend,ydis)

x=np.arange(xbegin,xend,xdis)

y=np.arange(ybegin,yend,ydis)
#x=np.arange(1,3,1)

#y=np.arange(1,4,1)
x = [4,5,7,10,14,19,25]
y = [500,1000,5000,10000,20000]
xnum = 7
ynum = 5
x,y=np.meshgrid(y,x)

#print(x)
#print(y)

# x,y=np.meshgrid(x,y)

# r=np.sqrt(x**2, y**2)
#x = np.loadtxt("initdiff-4-30-2-10-110-10.txt", skiprows=1,delimiter=",",usecols=(0,))
# y = np.loadtxt("initdiff-20-30-1-90-100-1.txt", skiprows=1,delimiter=",",usecols=(1,))
#data = np.loadtxt("initdiff-4-30-2-50-100-5.txt", skiprows=1,delimiter=",",usecols=(2,))
#data = np.loadtxt("initdiff-4-30-2-50-100-5-10t.txt", skiprows=1,delimiter=",",usecols=(2,))
data = np.loadtxt("initdiff.txt", skiprows=1,delimiter=",",usecols=(2,))
#data = np.loadtxt("initdiff-4-30-2-10-110-10.txt", skiprows=1,delimiter=",",usecols=(2,))

# z=np.sin(r)
dataList = []
for i in range(0,xnum):
    tmpList = []
    for j in range(0,ynum):
        tmpList.append(data[i*ynum+j])
    dataList.append(tmpList)
z=np.array(dataList)

#z = np.array([[1,1],[1,1],[1,1]])
#print(z)
#ax.plot_surface(x,y,z)
ax.plot_surface(x,y,z,rstride=1,cstride=1,cmap="rainbow")
#print(x)
#print(z)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
